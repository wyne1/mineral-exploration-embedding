# %%
from __future__ import annotations

import itertools
import math
from pathlib import Path
import re
from typing import Any, Iterable, Optional, Union
import warnings
import sys

import geopandas
import matplotlib
import matplotlib.axes
import matplotlib.cm
import matplotlib.figure
import matplotlib.pyplot
import mpl_toolkits.mplot3d
import numpy
import pandas
import plotly.graph_objs
# import seaborn
from shapely import Point
from sklearn.linear_model import LinearRegression
from scipy.optimize import Bounds
import scipy.stats

sys.path.append('../Packages/tectoniq')
from tectoniq.datasets import Mercedes
from tectoniq.functions import IFunction, Polynomial, Power, PowerWithOffset
from tectoniq.geometry import distance, distance_to_line, distance_to_line_segment
from tectoniq.optimization import fit_function


from sklearn import metrics
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

def min_max_scaling(data):
    """
    Perform Min-Max scaling on the input data.
    """
    scaler = MinMaxScaler()
    return pd.Series(scaler.fit_transform(data.values.reshape(-1, 1)).flatten(), index=data.index)

def standard_scaling(data):
    """
    Perform Standard scaling (z-score normalization) on the input data.
    """
    scaler = StandardScaler()
    return pd.Series(scaler.fit_transform(data.values.reshape(-1, 1)).flatten(), index=data.index)

def robust_scaling(data):
    """
    Perform Robust scaling on the input data.
    """
    scaler = RobustScaler()
    return pd.Series(scaler.fit_transform(data.values.reshape(-1, 1)).flatten(), index=data.index)

def log_transform(data):
    """
    Perform log transformation on the input data.
    Adds a small constant to avoid log(0).
    """
    return np.log(data + 1e-10)

def winsorization(data, limits=(0.05, 0.95)):
    """
    Perform Winsorization on the input data.
    """
    lower_limit = data.quantile(limits[0])
    upper_limit = data.quantile(limits[1])
    return data.clip(lower=lower_limit, upper=upper_limit)

def log_then_min_max(data):
    """
    Perform log transformation followed by Min-Max scaling.
    """
    log_data = log_transform(data)
    return min_max_scaling(log_data)

def winsor_then_min_max(data, limits=(0.05, 0.95)):
    """
    Perform Winsorization followed by Min-Max scaling.
    """
    winsor_data = winsorization(data, limits)
    return min_max_scaling(winsor_data)

    
def calculate_weights(differences, penalty_factor=1):
    # Higher penalty factor will penalize lower differences more
    return penalty_factor / (differences + penalty_factor)

def weighted_f1_score(data_frame, gold_threshold, ore_diff_threshold, penalty_factor=1):
    data_frame["Actual"] = data_frame[GOLD_COLUMN] >= gold_threshold
    data_frame["Predicted"] = data_frame[ORE_DIFFERENCE_COLUMN] <= ore_diff_threshold
    
    data_frame["Weight"] = calculate_weights(data_frame[ORE_DIFFERENCE_COLUMN], penalty_factor)
    
    tp = data_frame[data_frame["Actual"] & data_frame["Predicted"]]
    fp = data_frame[~data_frame["Actual"] & data_frame["Predicted"]]
    fn = data_frame[data_frame["Actual"] & ~data_frame["Predicted"]]
    tn = data_frame[~data_frame["Actual"] & ~data_frame["Predicted"]]
    
    weighted_tp = tp["Weight"].sum()
    weighted_fp = fp["Weight"].sum()
    weighted_fn = fn["Weight"].sum()
    weighted_tn = tn["Weight"].sum()
    
    weighted_accuracy = (weighted_tp + weighted_tn) / (weighted_tp + weighted_tn + weighted_fp + weighted_fn)
    weighted_precision = weighted_tp / (weighted_tp + weighted_fp)
    weighted_recall = weighted_tp / (weighted_tp + weighted_fn)
    
    if weighted_precision + weighted_recall == 0:
        return 0
    
    weighted_f1 = 2 * (weighted_precision * weighted_recall) / (weighted_precision + weighted_recall)
    
    return round(weighted_f1, 4), round(weighted_precision, 4), round(weighted_recall, 4), round(weighted_accuracy, 4), tp, fp, fn, tn

def penalty_function(ore_difference, max_penalty=10):
    return max_penalty / (ore_difference + 0.1)  

def custom_loss(data_frame, gold_threshold, ore_diff_threshold, max_penalty=10):
    data_frame["Actual"] = data_frame[GOLD_COLUMN] >= gold_threshold
    data_frame["Predicted"] = data_frame[ORE_DIFFERENCE_COLUMN] <= ore_diff_threshold
    
    false_positives = data_frame[~data_frame["Actual"] & data_frame["Predicted"]]
    false_negatives = data_frame[data_frame["Actual"] & ~data_frame["Predicted"]]
    
    fp_penalties = false_positives[ORE_DIFFERENCE_COLUMN].apply(penalty_function, max_penalty=max_penalty)
    fn_penalties = false_negatives[ORE_DIFFERENCE_COLUMN].apply(penalty_function, max_penalty=max_penalty)
    
    total_loss = fp_penalties.sum() + fn_penalties.sum()
    
    return total_loss

# %%
AREA_ID_COLUMN = Mercedes.AREA_ID_COLUMN
DOMAIN_ID_COLUMN = Mercedes.DOMAIN_ID_COLUMN
DOMAIN_NAME_COLUMN = Mercedes.DOMAIN_NAME_COLUMN
GEOMETRY_COLUMN = Mercedes.GEOMETRY_COLUMN
ID_COLUMN = Mercedes.ID_COLUMN
RADIUS: float = 20
SAMPLE_COUNT_THRESHOLD: int = 20
TARGET_COLUMN: str = "Au (ppm)"
THRESHOLD: float = 3

COPPER_COLUMN: str = "Cu (ppm)"
GOLD_COLUMN: str = "Au (ppm)"

COLUMN_FIT_OPTIONS: dict[str, dict[str, Any]] = {
    "(2Ca+Na+K)/Al": {},
    "K/Al": {},
    "As/Al": {},
    "K/(Al-Na)": {},
    "CCPI": {},
    "Ishikawa": {},
    "Na/Al": {},
    "Fe (%)": {},
    "Ca (%)": {},
    "Na (%)": {},
    "K (%)": {},
    "Al (%)": {},
    "As (ppm)": {},
    "Cu (ppm)": {},
    "Mg (%)": {}
}
COLUMN_LIMITS: dict[str, tuple[float, float]] = {
    "(2Ca+Na+K)/Al": (0, 2.5),
    "K/Al": (0, 1.5),
    "As/Al": (0, 2000),
    "K/(Al-Na)": (-0.25, 1.5),
    "CCPI": (0, 1),
    "Ishikawa": (0, 100),
    "Na/Al": (0, 1.5),
    "Fe (%)": (0, 10),
    "Ca (%)": (0, 30),
    "Na (%)": (0, 10),
    "K (%)": (0, 10),
    "Al (%)": (0, 10),
    "As (ppm)": (0, 600),
    "Cu (ppm)": (0, 300),
    "Mg (%)": (0, 5),
}

PLOT_TYPE_DENSITY: str = "density"

RATIO_COLUMNS: list[str] = ["(2Ca+Na+K)/Al", "K/Al", "As/Al", "K/(Al-Na)", "CCPI", "Ishikawa", "Na/Al"]
RATIO_CONSTITUTENT_COLUMNS: list[str] = ["Fe (%)", "Ca (%)", "Na (%)", "K (%)", "Al (%)", "As (ppm)", "Cu (ppm)", "Mg (%)"]
KEY_ELEMENT_COLUMNS: list[str] = ["Fe (%)", "Ca (%)", "Na (%)", "K (%)", "Al (%)", "Cu (ppm)", "Mg (%)"]
# KEY_ELEMENT_COLUMNS: list[str] = ["Fe (%)", "Ca (%)", "Na (%)", "K (%)", "Al (%)", "Mg (%)"]
# KEY_ELEMENT_COLUMNS: list[str] = ["Fe (%)", "Ca (%)", "Na (%)", "K (%)", "Al (%)", "Cu (ppm)", "Mg (%)", "Ishikawa", "CCPI"]

DOMAIN_1_SUBSET_LINE: tuple[Point, Point] = Point(549250, 3356800), Point(550000, 3355500)
NULL_DOMAIN_BOTTOM_LEFT = Point(551200, 3355600)
NULL_DOMAIN_TOP_RIGHT = Point(551500, 3355850)

AREA_1_RHYOLITE_SAMPLE_NUMBER = "MRS-016"
AREA_1_ANDESITE_SAMPLE_NUMBER = "MRS-032"
AREA_1_ORE_SAMPLE_NUMBER = "MRS-001"
AREA_2_LIMESTONE_SAMPLE_NUMBER = "MRS-023"
AREA_2_SILTSTONE_SAMPLE_NUMBER = "M023228"
KEY_SAMPLE_NUMBERS = [AREA_1_RHYOLITE_SAMPLE_NUMBER, AREA_1_ANDESITE_SAMPLE_NUMBER, AREA_1_ORE_SAMPLE_NUMBER, AREA_2_LIMESTONE_SAMPLE_NUMBER, AREA_2_SILTSTONE_SAMPLE_NUMBER]

matplotlib.interactive(True)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Experiments

# %%
import os

exp_dir = "/Users/zeerakwyne/Documents/redmarble/experiments"
os.listdir(exp_dir)

all_exp = pandas.DataFrame()
for file in os.listdir(exp_dir):
    if file.endswith(".csv"):
        df = pandas.read_csv(os.path.join(exp_dir, file))
        df['Experiment Name'] = file.split('.csv')[0]
        all_exp = pandas.concat([all_exp, df])

# all_exp = all_exp.drop(['Start Time', 'Duration', 'Run ID', 'Source Type', 'Source Name', 'User', 'Status', 'Accuracy'], axis =1)
all_exp = all_exp[['Experiment Name', 'Name', 'difference_threshold', 'normalization_vector', 'target_threshold',
       'Weighted accuracy', 'Weighted f1', 'Weighted precision',
       'Weighted recall', 'fn', 'fp', 'tn', 'tp', 'Loss']]
all_exp = all_exp.sort_values(by='Weighted f1', ascending=False).dropna()

display(all_exp.head())
# Out:
#                                  Experiment Name                  Name  \
# 70             Fe Ca Na K Al Mg CCPI Ishikawa As       salty-shoat-997
# 170  Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As  fearless-dolphin-408
# 50   Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As    indecisive-elk-411
# 0                       Fe Ca Na K Al Mg CCPI As       placid-moth-877
# 40                      Fe Ca Na K Al Mg CCPI As         funny-cow-508
#
#      difference_threshold                               normalization_vector  \
# 70                    2.5  [ 1.65 11.    0.55  0.55  2.2   0.55  0.44  0....
# 170                   2.5  [ 1.65 11.    0.55  0.55  2.2   0.55  0.44  0....
# 50                    2.5  [ 3.5  12.    0.6   0.6   4.    0.6   0.48  0....
# 0                     2.5  [ 1.575 10.5    0.525  0.525  2.1    0.525  0....
# 40                    2.5  [ 1.575 10.5    0.525  0.525  2.1    0.525  0....
#
#      target_threshold  Weighted accuracy  Weighted f1  Weighted precision  \
# 70               45.0             0.6816       0.2749              0.2028
# 170              45.0             0.6838       0.2713              0.2011
# 50               45.0             0.5474       0.2686              0.1740
# 0                45.0             0.6906       0.2665              0.2002
# 40               45.0             0.6906       0.2665              0.2002
#
#      Weighted recall     fn     fp      tn     tp        Loss
# 70            0.4268  158.0  283.0  1212.0   70.0  174.941447
# 170           0.4165  160.0  278.0  1217.0   68.0  172.409874
# 50            0.5883  124.0  514.0   981.0  104.0  283.479339
# 0             0.3986  164.0  263.0  1232.0   64.0  167.103023
# 40            0.3986  164.0  263.0  1232.0   64.0  167.103023

# %%
all_exp.to_excel('Area2_copper_experiments.xlsx', index=False)

# %%
all_exp['Experiment Name'] = all_exp['Experiment Name'].str.split('-').str[-1].str.strip()
# Out:
# 0                   Fe Ca Na K Al Mg
# 1                   Fe Ca Na K Al Mg
# 0                                Na)
# 1                                Na)
# 0     Fe Ca Na K Al Mg CCPI Ishikawa
#                    ...
# 74                  Fe Ca Na K Al Mg
# 75                  Fe Ca Na K Al Mg
# 76                  Fe Ca Na K Al Mg
# 77                  Fe Ca Na K Al Mg
# 78                  Fe Ca Na K Al Mg
# Name: Experiment Name, Length: 263, dtype: object

# %%
def normalize_ratio_columns(data_frame):
    temp_df = data_frame.copy()
    temp_df['(2Ca+Na+K)/Al'] = min_max_scaling(temp_df['(2Ca+Na+K)/Al'])
    temp_df['K/Al'] = log_then_min_max(temp_df['K/Al'])
    temp_df['As/Al'] = log_then_min_max(temp_df['As/Al'])
    temp_df['K/(Al-Na)'] = winsor_then_min_max(temp_df['K/(Al-Na)'])
    temp_df['CCPI'] = min_max_scaling(temp_df['CCPI'])
    temp_df['Ishikawa'] = min_max_scaling(temp_df['Ishikawa'])
    temp_df['Na/Al'] = min_max_scaling(temp_df['Na/Al'])
    temp_df['As (ppm)']  = robust_scaling(temp_df['As (ppm)'])
    return temp_df

# %% [markdown]
# ## Final Run

# %%
def get_units(column: str) -> Optional[str]:
    unit_match: re.Match = re.search(r"\((.+)\)", column)
    return unit_match.group() if unit_match else None

def print_df_summary(data_frame):
    total_rows = data_frame.shape[0]
    nan_count = data_frame[RATIO_COLUMNS + RATIO_CONSTITUTENT_COLUMNS].isna().sum()
    nan_percentage = (nan_count / total_rows) * 100
    nan_summary = pd.DataFrame({
        'NaN Count': nan_count,
        'NaN Percentage': nan_percentage
    })

    display(nan_summary.round(3))

# %%
data_frame: geopandas.GeoDataFrame = Mercedes.latest(Path("../Data"))

area_1_data_frame: geopandas.GeoDataFrame = data_frame[data_frame[AREA_ID_COLUMN] == 1]
area_2_data_frame: geopandas.GeoDataFrame = data_frame[data_frame[AREA_ID_COLUMN] == 2]
key_samples_data_frame: geopandas.GeoDataFrame = data_frame[data_frame[ID_COLUMN].isin(KEY_SAMPLE_NUMBERS)]

area_1_data_frame = normalize_ratio_columns(area_1_data_frame)
area_2_data_frame = normalize_ratio_columns(area_2_data_frame)

AREA_1_RHYOLITE_SAMPLE_NUMBER = "MRS-016"
AREA_1_ANDESITE_SAMPLE_NUMBER = "MRS-032"
AREA_1_ORE_SAMPLE_NUMBER = "MRS-001"
AREA_2_LIMESTONE_SAMPLE_NUMBER = "MRS-023"
AREA_2_SILTSTONE_SAMPLE_NUMBER = "M023228"
AREA_2_ORE_SAMPLE_NUMBER = "695588"

# %%
print(f"Initial Data Shape: {area_1_data_frame.shape}")
print(f"Initial Data Shape: {area_2_data_frame.shape}")
# Out:
# Initial Data Shape: (3443, 72)
# Initial Data Shape: (1723, 72)

# %%
area_1_data_frame = area_1_data_frame[~((area_1_data_frame['Fe (%)'] == 0) | (area_1_data_frame['Fe (%)'].isna())) & ~(area_1_data_frame['Ca (%)'] == 0)]
area_1_data_frame = area_1_data_frame[~(area_1_data_frame['Na (%)'].isna())].reset_index(drop=True)
area_2_data_frame = area_2_data_frame[~((area_2_data_frame['Fe (%)'] == 0) | (area_2_data_frame['Fe (%)'].isna())) & ~(area_2_data_frame['Ca (%)'] == 0)]
area_2_data_frame = area_2_data_frame[~(area_2_data_frame['Na (%)'].isna())].reset_index(drop=True)

# %%
print(f"Initial Data Shape: {area_1_data_frame.shape}")
print(f"Initial Data Shape: {area_2_data_frame.shape}")
# Out:
# Initial Data Shape: (3401, 72)
# Initial Data Shape: (1723, 72)

# %%
KEY_ELEMENT_COLUMNS = ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI']
AREA_1_ORE_VECTOR: numpy.array = numpy.array([2, 1, 0, 3, 3, 130, 0, 1])
AREA_1_ANDESITE_VECTOR: numpy.array = numpy.array([5, 4.5, 3, 2.5, 8.5, 30, 1.5, 0.5])
AREA_1_RHYOLITE_VECTOR: numpy.array = numpy.array([5, 5, 3, 2, 7.5, 5, 3, 0.5])
NORMALIZATION_VECTOR: numpy.array = numpy.array([6,6,4,3.5,10.5, 25, 4.5,0.6])

AREA_1_ORE_NORMALIZED_VECTOR: numpy.array = numpy.divide(AREA_1_ORE_VECTOR, NORMALIZATION_VECTOR)
AREA_1_ANDESITE_NORMALIZED_VECTOR: numpy.array = numpy.divide(AREA_1_ANDESITE_VECTOR, NORMALIZATION_VECTOR)
AREA_1_RHYOLITE_NORMALIZED_VECTOR: numpy.array = numpy.divide(AREA_1_RHYOLITE_VECTOR, NORMALIZATION_VECTOR)

NORMALIZED_VECTOR_COLUMN: str = "NormalizedVector"
ORE_DIFFERENCE_COLUMN: str = "OreDifference"

area_1_data_frame[NORMALIZED_VECTOR_COLUMN] = area_1_data_frame[KEY_ELEMENT_COLUMNS].apply(lambda x: numpy.divide(x.to_numpy(), NORMALIZATION_VECTOR), axis = 1)
area_1_data_frame[ORE_DIFFERENCE_COLUMN] = area_1_data_frame[NORMALIZED_VECTOR_COLUMN].apply(lambda x: numpy.linalg.norm(x - AREA_1_ORE_NORMALIZED_VECTOR))

# %%
GOLD_THRESHOLD = 2.5
DIFFERENCE_THRESHOLD = 2.5

area_1_data_frame["Actual"] = area_1_data_frame[GOLD_COLUMN].apply(lambda x: x>=GOLD_THRESHOLD)
area_1_data_frame["Predicted"] = area_1_data_frame[ORE_DIFFERENCE_COLUMN].apply(lambda x: x<=DIFFERENCE_THRESHOLD)

tp: int = len(area_1_data_frame[area_1_data_frame["Actual"] & area_1_data_frame["Predicted"]])
fp: int = len(area_1_data_frame[~area_1_data_frame["Actual"] & area_1_data_frame["Predicted"]])
fn: int = len(area_1_data_frame[area_1_data_frame["Actual"] & ~area_1_data_frame["Predicted"]])
tn: int = len(area_1_data_frame[~area_1_data_frame["Actual"] & ~area_1_data_frame["Predicted"]])

accuracy: float = (tp + tn) / (tp + tn + fp + fn)
precision: float = tp / (tp + fp)
recall: float = tp / (tp + fn)
f1_score: float = (2 * precision * recall) / (precision + recall)

print(f"True Positives = {round(tp, 4)} | False Positives = {round(fp, 4)} | False Negatives = {round(fn, 4)} | True Negatives = {round(tn, 4)}")
print(f"Accuracy = {round(accuracy, 4)} | Precision = {round(precision, 4)} | Recall = {round(recall, 4)} | F1 Score = {round(f1_score, 4)}")

area_1_data_frame['classification'] = ''
area_1_data_frame.loc[area_1_data_frame['Actual'] & area_1_data_frame['Predicted'], 'classification'] = 'TP'
area_1_data_frame.loc[area_1_data_frame['Actual'] & ~area_1_data_frame['Predicted'], 'classification'] = 'FN'
area_1_data_frame.loc[~area_1_data_frame['Actual'] & area_1_data_frame['Predicted'], 'classification'] = 'FP'
area_1_data_frame.loc[~area_1_data_frame['Actual'] & ~area_1_data_frame['Predicted'], 'classification'] = 'TN'
# Out:
# True Positives = 30 | False Positives = 136 | False Negatives = 85 | True Negatives = 3150
# Accuracy = 0.935 | Precision = 0.1807 | Recall = 0.2609 | F1 Score = 0.2135

# %%
all_exp['Experiment Name'].unique()
# Out:
# array(['Fe Ca Na K Al Mg CCPI Ishikawa As',
#        'Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As',
#        'Fe Ca Na K Al Mg CCPI As'], dtype=object)

# %%
# Mapping dictionary
mapping = {
    # 'Fe Ca Na K Al Cu Mg CCPI': ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI'],
    # 'Fe Ca Na K Al Cu Mg CCPI Ishikawa NaAl': ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI', 'Ishikawa', 'Na/Al'],
    # 'Fe Ca Na K Al Cu Mg CCPI Ishikawa': ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI', 'Ishikawa'],
    # 'Fe K Al Cu CCPI K_(Al-Na) As_Al': ['Fe (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'CCPI', 'K/(Al-Na)', 'As/Al'],
    # 'Fe Ca Na K Al Mg' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)'],
    # 'Fe Ca Na K Al Mg CCPI Ishikawa' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa'],
    # 'Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na)' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)'],
    'Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)'],
    'Fe Ca Na K Al Mg CCPI Ishikawa As' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa','As (ppm)'],
    'Fe Ca Na K Al Mg CCPI As' : ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI','As (ppm)']
}


all_exp['Key Columns'] = all_exp['Experiment Name'].map(mapping)

mapping = {
    # 'Fe Ca Na K Al Cu Mg CCPI': [1, 3, 0, 0.5, 1.5, 15, 0, 0.5],
    # 'Fe Ca Na K Al Cu Mg CCPI Ishikawa NaAl': [1, 3, 0, 0.5, 1.5, 15, 0, 0.5, 0.7, 0],
    # 'Fe Ca Na K Al Cu Mg CCPI Ishikawa': [1, 3, 0, 0.5, 1.5, 15, 0, 0.5, 0.7],
    # 'Fe K Al Cu CCPI K_(Al-Na) As_Al': [2, 5, 3, 130, 1, 0.6, 0.8],
    # 'Fe Ca Na K Al Mg' : [3, 1, 0, 3, 5, 0],
    # 'Fe Ca Na K Al Mg CCPI Ishikawa' : [3, 1, 0, 3, 5, 0, 1, 1],
    # 'Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na)' : [3, 1, 0, 3, 5, 0, 1, 1, 1],
    'Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As' : [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1],
    'Fe Ca Na K Al Mg CCPI Ishikawa As' : [4, 4, 1, 2, 6, 1, 0.6, 0.5, 1],
    'Fe Ca Na K Al Mg CCPI As' : [4, 4, 1, 2, 6, 1, 0.6, 1]
}

all_exp['area_1_ore'] = all_exp['Experiment Name'].map(mapping)
# Create the new column 'Key Columns'

# %%
all_exp = all_exp[all_exp['target_threshold'] == 45].sort_values(by='Weighted f1', ascending=False).head(100)

# all_exp = all_exp.sort_values(by='Weighted f1', ascending=False).head(100)

# %%
all_exp
# Out:
#                                  Experiment Name                  Name  \
# 70             Fe Ca Na K Al Mg CCPI Ishikawa As       salty-shoat-997
# 170  Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As  fearless-dolphin-408
# 50   Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As    indecisive-elk-411
# 40                      Fe Ca Na K Al Mg CCPI As         funny-cow-508
# 0                       Fe Ca Na K Al Mg CCPI As       placid-moth-877
# ..                                           ...                   ...
# 4    Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As      upset-shrimp-885
# 44   Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As        masked-eel-995
# 174  Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As     handsome-goat-896
# 94             Fe Ca Na K Al Mg CCPI Ishikawa As   honorable-skunk-360
# 194  Fe Ca Na K Al Mg CCPI Ishikawa K_(Al-Na) As     whimsical-yak-925
#
#      difference_threshold                               normalization_vector  \
# 70                    2.5  [ 1.65 11.    0.55  0.55  2.2   0.55  0.44  0....
# 170                   2.5  [ 1.65 11.    0.55  0.55  2.2   0.55  0.44  0....
# 50                    2.5  [ 3.5  12.    0.6   0.6   4.    0.6   0.48  0....
# 40                    2.5  [ 1.575 10.5    0.525  0.525  2.1    0.525  0....
# 0                     2.5  [ 1.575 10.5    0.525  0.525  2.1    0.525  0....
# ..                    ...                                                ...
# 4                     1.5  [ 2.    10.5    0.525  0.525  2.5    0.525  0....
# 44                    1.5  [ 2.    10.5    0.525  0.525  2.5    0.525  0....
# 174                   1.5  [ 1.65 11.    0.55  0.55  2.2   0.55  0.44  0....
# 94                    1.5     [ 1.5 10.   0.5  0.5  2.   0.5  0.4  0.3  0.5]
# 194                   1.5  [ 1.5 10.   0.5  0.5  2.   0.5  0.4  0.3  0.5 ...
#
#      target_threshold  Weighted accuracy  Weighted f1  Weighted precision  \
# 70               45.0             0.6816       0.2749              0.2028
# 170              45.0             0.6838       0.2713              0.2011
# 50               45.0             0.5474       0.2686              0.1740
# 40               45.0             0.6906       0.2665              0.2002
# 0                45.0             0.6906       0.2665              0.2002
# ..                ...                ...          ...                 ...
# 4                45.0             0.8502       0.0970              0.3305
# 44               45.0             0.8502       0.0970              0.3305
# 174              45.0             0.8506       0.0956              0.3309
# 94               45.0             0.8618       0.0925              0.6657
# 194              45.0             0.8618       0.0916              0.6636
#
#      Weighted recall     fn     fp      tn     tp        Loss  \
# 70            0.4268  158.0  283.0  1212.0   70.0  174.941447
# 170           0.4165  160.0  278.0  1217.0   68.0  172.409874
# 50            0.5883  124.0  514.0   981.0  104.0  283.479339
# 40            0.3986  164.0  263.0  1232.0   64.0  167.103023
# 0             0.3986  164.0  263.0  1232.0   64.0  167.103023
# ..               ...    ...    ...     ...    ...         ...
# 4             0.0569  221.0   15.0  1480.0    7.0   78.340319
# 44            0.0569  221.0   15.0  1480.0    7.0   78.340319
# 174           0.0559  221.0   15.0  1480.0    7.0   79.313766
# 94            0.0497  222.0    3.0  1492.0    6.0   66.375780
# 194           0.0492  222.0    3.0  1492.0    6.0   65.855229
#
#                                            Key Columns  \
# 70   [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 170  [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 50   [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 40   [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 0    [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# ..                                                 ...
# 4    [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 44   [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 174  [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 94   [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
# 194  [Fe (%), Ca (%), Na (%), K (%), Al (%), Mg (%)...
#
#                                area_1_ore
# 70        [4, 4, 1, 2, 6, 1, 0.6, 0.5, 1]
# 170  [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
# 50   [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
# 40             [4, 4, 1, 2, 6, 1, 0.6, 1]
# 0              [4, 4, 1, 2, 6, 1, 0.6, 1]
# ..                                    ...
# 4    [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
# 44   [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
# 174  [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
# 94        [4, 4, 1, 2, 6, 1, 0.6, 0.5, 1]
# 194  [4, 4, 1, 2, 6, 1, 0.6, 0.5, 0.5, 1]
#
# [100 rows x 16 columns]

# %%
import re

# %%
AREA_2_ORE_VECTOR: numpy.array = numpy.array([1, 3, 0, 0.5, 1.5, 15, 0, 0.5, 0.7, 0])
NORMALIZATION_VECTOR: numpy.array = np.array([3, 5, 1, 2, 6, 30, 1, 0.5, 0.8, 0.2])
AREA_1_ORE_NORMALIZED_VECTOR: numpy.array = numpy.divide(AREA_2_ORE_VECTOR, NORMALIZATION_VECTOR)

# %%
area_1_data_frame = area_2_data_frame.copy()

# %%
temp_df['area_1_ore']
# Out:
# 96    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 17    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 97    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 57    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 18    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 19    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 58    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 16    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 98    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 59    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 99    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 56    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 94    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 95    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 93    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# 92    [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1]
# Name: area_1_ore, dtype: object

# %%
all_exp['area_1_ore']
# Out:
# 0      [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# 1      [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# 2      [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# 3      [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# 111              [2, 1, 0, 3, 3, 130, 0, 1]
#                        ...
# 136              [2, 1, 0, 3, 3, 130, 0, 1]
# 46     [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# 78               [2, 1, 0, 3, 3, 130, 0, 1]
# 139              [2, 1, 0, 3, 3, 130, 0, 1]
# 47     [2, 1, 1, 5, 3, 130, 0.5, 0.5, 1, 0]
# Name: area_1_ore, Length: 100, dtype: object

# %%
# Out:
# 3

# %%
COPPER_THRESHOLD = 45
# DIFFERENCE_THRESHOLD = 2.5

exp_count = 0
for key_columns in all_exp['Key Columns'].astype(str).unique():
    temp_df = all_exp[all_exp['Key Columns'].astype(str) == key_columns].copy()
    for i in range(temp_df.shape[0]):
        KEY_ELEMENT_COLUMNS = eval(key_columns)
        TARGET_THRESHOLD = temp_df.iloc[i]['target_threshold']
        DIFFERENCE_THRESHOLD = temp_df.iloc[i]['difference_threshold']
        AREA_1_ORE_VECTOR = temp_df.iloc[i]['area_1_ore']
        NORMALIZATION_VECTOR = [float(num) for num in re.findall(r"[-+]?\d*\.\d+|\d+", temp_df.iloc[i]['normalization_vector'])]

        AREA_1_ORE_NORMALIZED_VECTOR: numpy.array = numpy.divide(AREA_1_ORE_VECTOR, NORMALIZATION_VECTOR)
        print(f"GOLD: {TARGET_THRESHOLD}\nNORM VECTOR: {NORMALIZATION_VECTOR}\nCOL: {KEY_ELEMENT_COLUMNS}")
        
        NORMALIZED_VECTOR_COLUMN: str = "NormalizedVector"
        ORE_DIFFERENCE_COLUMN: str = "OreDifference"

        area_1_data_frame[NORMALIZED_VECTOR_COLUMN] = area_1_data_frame[KEY_ELEMENT_COLUMNS].apply(lambda x: numpy.divide(x.to_numpy(), NORMALIZATION_VECTOR), axis = 1)
        area_1_data_frame[ORE_DIFFERENCE_COLUMN] = area_1_data_frame[NORMALIZED_VECTOR_COLUMN].apply(lambda x: numpy.linalg.norm(x - AREA_1_ORE_NORMALIZED_VECTOR))

        area_1_data_frame["Actual"] = area_1_data_frame[COPPER_COLUMN].apply(lambda x: x>=COPPER_THRESHOLD)
        area_1_data_frame["Predicted"] = area_1_data_frame[ORE_DIFFERENCE_COLUMN].apply(lambda x: x<=DIFFERENCE_THRESHOLD)

        tp: int = len(area_1_data_frame[area_1_data_frame["Actual"] & area_1_data_frame["Predicted"]])
        fp: int = len(area_1_data_frame[~area_1_data_frame["Actual"] & area_1_data_frame["Predicted"]])
        fn: int = len(area_1_data_frame[area_1_data_frame["Actual"] & ~area_1_data_frame["Predicted"]])
        tn: int = len(area_1_data_frame[~area_1_data_frame["Actual"] & ~area_1_data_frame["Predicted"]])

        try:
            accuracy: float = (tp + tn) / (tp + tn + fp + fn)
        except ZeroDivisionError:
            accuracy = 0

        try:
            precision: float = tp / (tp + fp)
        except ZeroDivisionError:
            precision = 0

        try:
            recall: float = tp / (tp + fn)
        except ZeroDivisionError:
            recall = 0

        try:
            f1_score: float = (2 * precision * recall) / (precision + recall)
        except ZeroDivisionError:
            f1_score = 0

        print(f"True Positives = {round(tp, 4)} | False Positives = {round(fp, 4)} | False Negatives = {round(fn, 4)} | True Negatives = {round(tn, 4)}")
        print(f"Accuracy = {round(accuracy, 4)} | Precision = {round(precision, 4)} | Recall = {round(recall, 4)} | F1 Score = {round(f1_score, 4)}\n")

        col_name = f"exp_{exp_count}_{i}"
        area_1_data_frame[col_name] = ''
        area_1_data_frame.loc[area_1_data_frame['Actual'] & area_1_data_frame['Predicted'], col_name] = 'TP'
        area_1_data_frame.loc[area_1_data_frame['Actual'] & ~area_1_data_frame['Predicted'], col_name] = 'FN'
        area_1_data_frame.loc[~area_1_data_frame['Actual'] & area_1_data_frame['Predicted'], col_name] = 'FP'
        area_1_data_frame.loc[~area_1_data_frame['Actual'] & ~area_1_data_frame['Predicted'], col_name] = 'TN'
    exp_count+=1
    # break
# Out:
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 70 | False Positives = 283 | False Negatives = 158 | True Negatives = 1212
# Accuracy = 0.7441 | Precision = 0.1983 | Recall = 0.307 | F1 Score = 0.241
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 73 | False Positives = 343 | False Negatives = 155 | True Negatives = 1152
# Accuracy = 0.711 | Precision = 0.1755 | Recall = 0.3202 | F1 Score = 0.2267
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 57 | False Positives = 239 | False Negatives = 171 | True Negatives = 1256
# Accuracy = 0.762 | Precision = 0.1926 | Recall = 0.25 | F1 Score = 0.2176
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 57 | False Positives = 239 | False Negatives = 171 | True Negatives = 1256
# Accuracy = 0.762 | Precision = 0.1926 | Recall = 0.25 | F1 Score = 0.2176
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 83 | False Positives = 440 | False Negatives = 145 | True Negatives = 1055
# Accuracy = 0.6605 | Precision = 0.1587 | Recall = 0.364 | F1 Score = 0.221
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 43 | False Positives = 164 | False Negatives = 185 | True Negatives = 1331
# Accuracy = 0.7974 | Precision = 0.2077 | Recall = 0.1886 | F1 Score = 0.1977
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 46 | False Positives = 194 | False Negatives = 182 | True Negatives = 1301
# Accuracy = 0.7818 | Precision = 0.1917 | Recall = 0.2018 | F1 Score = 0.1966
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.285, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 39 | False Positives = 150 | False Negatives = 189 | True Negatives = 1345
# Accuracy = 0.8033 | Precision = 0.2063 | Recall = 0.1711 | F1 Score = 0.1871
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 36 | False Positives = 129 | False Negatives = 192 | True Negatives = 1366
# Accuracy = 0.8137 | Precision = 0.2182 | Recall = 0.1579 | F1 Score = 0.1832
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 36 | False Positives = 129 | False Negatives = 192 | True Negatives = 1366
# Accuracy = 0.8137 | Precision = 0.2182 | Recall = 0.1579 | F1 Score = 0.1832
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 35 | False Positives = 119 | False Negatives = 193 | True Negatives = 1376
# Accuracy = 0.8189 | Precision = 0.2273 | Recall = 0.1535 | F1 Score = 0.1832
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 37 | False Positives = 137 | False Negatives = 191 | True Negatives = 1358
# Accuracy = 0.8096 | Precision = 0.2126 | Recall = 0.1623 | F1 Score = 0.1841
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.24, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 23 | False Positives = 69 | False Negatives = 205 | True Negatives = 1426
# Accuracy = 0.841 | Precision = 0.25 | Recall = 0.1009 | F1 Score = 0.1437
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 23 | False Positives = 69 | False Negatives = 205 | True Negatives = 1426
# Accuracy = 0.841 | Precision = 0.25 | Recall = 0.1009 | F1 Score = 0.1437
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 24 | False Positives = 95 | False Negatives = 204 | True Negatives = 1400
# Accuracy = 0.8265 | Precision = 0.2017 | Recall = 0.1053 | F1 Score = 0.1383
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 24 | False Positives = 95 | False Negatives = 204 | True Negatives = 1400
# Accuracy = 0.8265 | Precision = 0.2017 | Recall = 0.1053 | F1 Score = 0.1383
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.285, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 18 | False Positives = 53 | False Negatives = 210 | True Negatives = 1442
# Accuracy = 0.8474 | Precision = 0.2535 | Recall = 0.0789 | F1 Score = 0.1204
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 15 | False Positives = 35 | False Negatives = 213 | True Negatives = 1460
# Accuracy = 0.8561 | Precision = 0.3 | Recall = 0.0658 | F1 Score = 0.1079
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 15 | False Positives = 35 | False Negatives = 213 | True Negatives = 1460
# Accuracy = 0.8561 | Precision = 0.3 | Recall = 0.0658 | F1 Score = 0.1079
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 15 | False Positives = 35 | False Negatives = 213 | True Negatives = 1460
# Accuracy = 0.8561 | Precision = 0.3 | Recall = 0.0658 | F1 Score = 0.1079
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 13 | False Positives = 22 | False Negatives = 215 | True Negatives = 1473
# Accuracy = 0.8624 | Precision = 0.3714 | Recall = 0.057 | F1 Score = 0.0989
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 9 | False Positives = 17 | False Negatives = 219 | True Negatives = 1478
# Accuracy = 0.863 | Precision = 0.3462 | Recall = 0.0395 | F1 Score = 0.0709
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.24, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 7 | False Positives = 11 | False Negatives = 221 | True Negatives = 1484
# Accuracy = 0.8654 | Precision = 0.3889 | Recall = 0.0307 | F1 Score = 0.0569
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 7 | False Positives = 10 | False Negatives = 221 | True Negatives = 1485
# Accuracy = 0.8659 | Precision = 0.4118 | Recall = 0.0307 | F1 Score = 0.0571
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 7 | False Positives = 10 | False Negatives = 221 | True Negatives = 1485
# Accuracy = 0.8659 | Precision = 0.4118 | Recall = 0.0307 | F1 Score = 0.0571
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'As (ppm)']
# True Positives = 6 | False Positives = 3 | False Negatives = 222 | True Negatives = 1492
# Accuracy = 0.8694 | Precision = 0.6667 | Recall = 0.0263 | F1 Score = 0.0506
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 68 | False Positives = 278 | False Negatives = 160 | True Negatives = 1217
# Accuracy = 0.7458 | Precision = 0.1965 | Recall = 0.2982 | F1 Score = 0.2369
#
# GOLD: 45.0
# NORM VECTOR: [3.5, 12.0, 0.6, 0.6, 4.0, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 104 | False Positives = 514 | False Negatives = 124 | True Negatives = 981
# Accuracy = 0.6297 | Precision = 0.1683 | Recall = 0.4561 | F1 Score = 0.2459
#
# GOLD: 45.0
# NORM VECTOR: [2.5, 11.0, 0.55, 0.55, 3.0, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 72 | False Positives = 326 | False Negatives = 156 | True Negatives = 1169
# Accuracy = 0.7203 | Precision = 0.1809 | Recall = 0.3158 | F1 Score = 0.23
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 61 | False Positives = 258 | False Negatives = 167 | True Negatives = 1237
# Accuracy = 0.7533 | Precision = 0.1912 | Recall = 0.2675 | F1 Score = 0.223
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 61 | False Positives = 258 | False Negatives = 167 | True Negatives = 1237
# Accuracy = 0.7533 | Precision = 0.1912 | Recall = 0.2675 | F1 Score = 0.223
#
# GOLD: 45.0
# NORM VECTOR: [3.5, 12.0, 0.6, 0.6, 4.0, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 54 | False Positives = 210 | False Negatives = 174 | True Negatives = 1285
# Accuracy = 0.7771 | Precision = 0.2045 | Recall = 0.2368 | F1 Score = 0.2195
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 72 | False Positives = 333 | False Negatives = 156 | True Negatives = 1162
# Accuracy = 0.7162 | Precision = 0.1778 | Recall = 0.3158 | F1 Score = 0.2275
#
# GOLD: 45.0
# NORM VECTOR: [3.0, 11.5, 0.575, 0.575, 3.5, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 84 | False Positives = 416 | False Negatives = 144 | True Negatives = 1079
# Accuracy = 0.675 | Precision = 0.168 | Recall = 0.3684 | F1 Score = 0.2308
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 81 | False Positives = 423 | False Negatives = 147 | True Negatives = 1072
# Accuracy = 0.6692 | Precision = 0.1607 | Recall = 0.3553 | F1 Score = 0.2213
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 54 | False Positives = 235 | False Negatives = 174 | True Negatives = 1260
# Accuracy = 0.7626 | Precision = 0.1869 | Recall = 0.2368 | F1 Score = 0.2089
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 54 | False Positives = 235 | False Negatives = 174 | True Negatives = 1260
# Accuracy = 0.7626 | Precision = 0.1869 | Recall = 0.2368 | F1 Score = 0.2089
#
# GOLD: 45.0
# NORM VECTOR: [3.0, 11.5, 0.575, 0.575, 3.5, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 45 | False Positives = 172 | False Negatives = 183 | True Negatives = 1323
# Accuracy = 0.794 | Precision = 0.2074 | Recall = 0.1974 | F1 Score = 0.2022
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 46 | False Positives = 189 | False Negatives = 182 | True Negatives = 1306
# Accuracy = 0.7847 | Precision = 0.1957 | Recall = 0.2018 | F1 Score = 0.1987
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 46 | False Positives = 189 | False Negatives = 182 | True Negatives = 1306
# Accuracy = 0.7847 | Precision = 0.1957 | Recall = 0.2018 | F1 Score = 0.1987
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 41 | False Positives = 154 | False Negatives = 187 | True Negatives = 1341
# Accuracy = 0.8021 | Precision = 0.2103 | Recall = 0.1798 | F1 Score = 0.1939
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.285, 0.475, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 39 | False Positives = 147 | False Negatives = 189 | True Negatives = 1348
# Accuracy = 0.805 | Precision = 0.2097 | Recall = 0.1711 | F1 Score = 0.1884
#
# GOLD: 45.0
# NORM VECTOR: [2.5, 11.0, 0.55, 0.55, 3.0, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 37 | False Positives = 138 | False Negatives = 191 | True Negatives = 1357
# Accuracy = 0.8091 | Precision = 0.2114 | Recall = 0.1623 | F1 Score = 0.1836
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 35 | False Positives = 127 | False Negatives = 193 | True Negatives = 1368
# Accuracy = 0.8143 | Precision = 0.216 | Recall = 0.1535 | F1 Score = 0.1795
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 35 | False Positives = 127 | False Negatives = 193 | True Negatives = 1368
# Accuracy = 0.8143 | Precision = 0.216 | Recall = 0.1535 | F1 Score = 0.1795
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 34 | False Positives = 118 | False Negatives = 194 | True Negatives = 1377
# Accuracy = 0.8189 | Precision = 0.2237 | Recall = 0.1491 | F1 Score = 0.1789
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 36 | False Positives = 135 | False Negatives = 192 | True Negatives = 1360
# Accuracy = 0.8102 | Precision = 0.2105 | Recall = 0.1579 | F1 Score = 0.1805
#
# GOLD: 45.0
# NORM VECTOR: [1.0, 9.5, 0.475, 0.475, 1.5, 0.475, 0.38, 0.285, 0.475, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 33 | False Positives = 117 | False Negatives = 195 | True Negatives = 1378
# Accuracy = 0.8189 | Precision = 0.22 | Recall = 0.1447 | F1 Score = 0.1746
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 30 | False Positives = 111 | False Negatives = 198 | True Negatives = 1384
# Accuracy = 0.8207 | Precision = 0.2128 | Recall = 0.1316 | F1 Score = 0.1626
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 30 | False Positives = 111 | False Negatives = 198 | True Negatives = 1384
# Accuracy = 0.8207 | Precision = 0.2128 | Recall = 0.1316 | F1 Score = 0.1626
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.24, 0.4, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 23 | False Positives = 66 | False Negatives = 205 | True Negatives = 1429
# Accuracy = 0.8427 | Precision = 0.2584 | Recall = 0.1009 | F1 Score = 0.1451
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 23 | False Positives = 66 | False Negatives = 205 | True Negatives = 1429
# Accuracy = 0.8427 | Precision = 0.2584 | Recall = 0.1009 | F1 Score = 0.1451
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 23 | False Positives = 66 | False Negatives = 205 | True Negatives = 1429
# Accuracy = 0.8427 | Precision = 0.2584 | Recall = 0.1009 | F1 Score = 0.1451
#
# GOLD: 45.0
# NORM VECTOR: [3.5, 12.0, 0.6, 0.6, 4.0, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 23 | False Positives = 65 | False Negatives = 205 | True Negatives = 1430
# Accuracy = 0.8433 | Precision = 0.2614 | Recall = 0.1009 | F1 Score = 0.1456
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 24 | False Positives = 92 | False Negatives = 204 | True Negatives = 1403
# Accuracy = 0.8282 | Precision = 0.2069 | Recall = 0.1053 | F1 Score = 0.1395
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 24 | False Positives = 92 | False Negatives = 204 | True Negatives = 1403
# Accuracy = 0.8282 | Precision = 0.2069 | Recall = 0.1053 | F1 Score = 0.1395
#
# GOLD: 45.0
# NORM VECTOR: [3.0, 11.5, 0.575, 0.575, 3.5, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 18 | False Positives = 47 | False Negatives = 210 | True Negatives = 1448
# Accuracy = 0.8508 | Precision = 0.2769 | Recall = 0.0789 | F1 Score = 0.1229
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.285, 0.475, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 16 | False Positives = 47 | False Negatives = 212 | True Negatives = 1448
# Accuracy = 0.8497 | Precision = 0.254 | Recall = 0.0702 | F1 Score = 0.11
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 14 | False Positives = 29 | False Negatives = 214 | True Negatives = 1466
# Accuracy = 0.859 | Precision = 0.3256 | Recall = 0.0614 | F1 Score = 0.1033
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 14 | False Positives = 29 | False Negatives = 214 | True Negatives = 1466
# Accuracy = 0.859 | Precision = 0.3256 | Recall = 0.0614 | F1 Score = 0.1033
#
# GOLD: 45.0
# NORM VECTOR: [2.5, 11.0, 0.55, 0.55, 3.0, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 14 | False Positives = 26 | False Negatives = 214 | True Negatives = 1469
# Accuracy = 0.8607 | Precision = 0.35 | Recall = 0.0614 | F1 Score = 0.1045
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.36, 0.6, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 14 | False Positives = 29 | False Negatives = 214 | True Negatives = 1466
# Accuracy = 0.859 | Precision = 0.3256 | Recall = 0.0614 | F1 Score = 0.1033
#
# GOLD: 45.0
# NORM VECTOR: [1.0, 9.5, 0.475, 0.475, 1.5, 0.475, 0.38, 0.285, 0.475, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 13 | False Positives = 23 | False Negatives = 215 | True Negatives = 1472
# Accuracy = 0.8619 | Precision = 0.3611 | Recall = 0.057 | F1 Score = 0.0985
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.345, 0.575, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 12 | False Positives = 20 | False Negatives = 216 | True Negatives = 1475
# Accuracy = 0.863 | Precision = 0.375 | Recall = 0.0526 | F1 Score = 0.0923
#
# GOLD: 45.0
# NORM VECTOR: [0.5, 9.0, 0.45, 0.45, 1.0, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 8 | False Positives = 17 | False Negatives = 220 | True Negatives = 1478
# Accuracy = 0.8624 | Precision = 0.32 | Recall = 0.0351 | F1 Score = 0.0632
#
# GOLD: 45.0
# NORM VECTOR: [0.5, 9.0, 0.45, 0.45, 1.0, 0.45, 0.36, 0.27, 0.45, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 8 | False Positives = 17 | False Negatives = 220 | True Negatives = 1478
# Accuracy = 0.8624 | Precision = 0.32 | Recall = 0.0351 | F1 Score = 0.0632
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.24, 0.4, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 10 | False Negatives = 221 | True Negatives = 1485
# Accuracy = 0.8659 | Precision = 0.4118 | Recall = 0.0307 | F1 Score = 0.0571
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 8 | False Negatives = 221 | True Negatives = 1487
# Accuracy = 0.8671 | Precision = 0.4667 | Recall = 0.0307 | F1 Score = 0.0576
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 8 | False Negatives = 221 | True Negatives = 1487
# Accuracy = 0.8671 | Precision = 0.4667 | Recall = 0.0307 | F1 Score = 0.0576
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 15 | False Negatives = 221 | True Negatives = 1480
# Accuracy = 0.863 | Precision = 0.3182 | Recall = 0.0307 | F1 Score = 0.056
#
# GOLD: 45.0
# NORM VECTOR: [2.0, 10.5, 0.525, 0.525, 2.5, 0.525, 0.42, 0.315, 0.525, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 15 | False Negatives = 221 | True Negatives = 1480
# Accuracy = 0.863 | Precision = 0.3182 | Recall = 0.0307 | F1 Score = 0.056
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.33, 0.55, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 7 | False Positives = 15 | False Negatives = 221 | True Negatives = 1480
# Accuracy = 0.863 | Precision = 0.3182 | Recall = 0.0307 | F1 Score = 0.056
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.3, 0.5, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'Ishikawa', 'K/(Al-Na)', 'As (ppm)']
# True Positives = 6 | False Positives = 3 | False Negatives = 222 | True Negatives = 1492
# Accuracy = 0.8694 | Precision = 0.6667 | Recall = 0.0263 | F1 Score = 0.0506
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 64 | False Positives = 263 | False Negatives = 164 | True Negatives = 1232
# Accuracy = 0.7522 | Precision = 0.1957 | Recall = 0.2807 | F1 Score = 0.2306
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 64 | False Positives = 263 | False Negatives = 164 | True Negatives = 1232
# Accuracy = 0.7522 | Precision = 0.1957 | Recall = 0.2807 | F1 Score = 0.2306
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 71 | False Positives = 316 | False Negatives = 157 | True Negatives = 1179
# Accuracy = 0.7255 | Precision = 0.1835 | Recall = 0.3114 | F1 Score = 0.2309
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 76 | False Positives = 385 | False Negatives = 152 | True Negatives = 1110
# Accuracy = 0.6883 | Precision = 0.1649 | Recall = 0.3333 | F1 Score = 0.2206
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 90 | False Positives = 484 | False Negatives = 138 | True Negatives = 1011
# Accuracy = 0.639 | Precision = 0.1568 | Recall = 0.3947 | F1 Score = 0.2244
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 51 | False Positives = 221 | False Negatives = 177 | True Negatives = 1274
# Accuracy = 0.769 | Precision = 0.1875 | Recall = 0.2237 | F1 Score = 0.204
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 45 | False Positives = 181 | False Negatives = 183 | True Negatives = 1314
# Accuracy = 0.7887 | Precision = 0.1991 | Recall = 0.1974 | F1 Score = 0.1982
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 46 | False Positives = 188 | False Negatives = 182 | True Negatives = 1307
# Accuracy = 0.7853 | Precision = 0.1966 | Recall = 0.2018 | F1 Score = 0.1991
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 39 | False Positives = 147 | False Negatives = 189 | True Negatives = 1348
# Accuracy = 0.805 | Precision = 0.2097 | Recall = 0.1711 | F1 Score = 0.1884
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 39 | False Positives = 147 | False Negatives = 189 | True Negatives = 1348
# Accuracy = 0.805 | Precision = 0.2097 | Recall = 0.1711 | F1 Score = 0.1884
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 37 | False Positives = 137 | False Negatives = 191 | True Negatives = 1358
# Accuracy = 0.8096 | Precision = 0.2126 | Recall = 0.1623 | F1 Score = 0.1841
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 40 | False Positives = 159 | False Negatives = 188 | True Negatives = 1336
# Accuracy = 0.7986 | Precision = 0.201 | Recall = 0.1754 | F1 Score = 0.1874
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 24 | False Positives = 91 | False Negatives = 204 | True Negatives = 1404
# Accuracy = 0.8288 | Precision = 0.2087 | Recall = 0.1053 | F1 Score = 0.1399
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 27 | False Positives = 113 | False Negatives = 201 | True Negatives = 1382
# Accuracy = 0.8178 | Precision = 0.1929 | Recall = 0.1184 | F1 Score = 0.1467
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 27 | False Positives = 113 | False Negatives = 201 | True Negatives = 1382
# Accuracy = 0.8178 | Precision = 0.1929 | Recall = 0.1184 | F1 Score = 0.1467
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 24 | False Positives = 91 | False Negatives = 204 | True Negatives = 1404
# Accuracy = 0.8288 | Precision = 0.2087 | Recall = 0.1053 | F1 Score = 0.1399
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 20 | False Positives = 69 | False Negatives = 208 | True Negatives = 1426
# Accuracy = 0.8392 | Precision = 0.2247 | Recall = 0.0877 | F1 Score = 0.1262
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 16 | False Positives = 47 | False Negatives = 212 | True Negatives = 1448
# Accuracy = 0.8497 | Precision = 0.254 | Recall = 0.0702 | F1 Score = 0.11
#
# GOLD: 45.0
# NORM VECTOR: [1.35, 9.0, 0.45, 0.45, 1.8, 0.45, 0.36, 0.45]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 16 | False Positives = 47 | False Negatives = 212 | True Negatives = 1448
# Accuracy = 0.8497 | Precision = 0.254 | Recall = 0.0702 | F1 Score = 0.11
#
# GOLD: 45.0
# NORM VECTOR: [1.725, 11.5, 0.575, 0.575, 2.3, 0.575, 0.46, 0.575]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 15 | False Positives = 34 | False Negatives = 213 | True Negatives = 1461
# Accuracy = 0.8566 | Precision = 0.3061 | Recall = 0.0658 | F1 Score = 0.1083
#
# GOLD: 45.0
# NORM VECTOR: [1.8, 12.0, 0.6, 0.6, 2.4, 0.6, 0.48, 0.6]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 16 | False Positives = 47 | False Negatives = 212 | True Negatives = 1448
# Accuracy = 0.8497 | Precision = 0.254 | Recall = 0.0702 | F1 Score = 0.11
#
# GOLD: 45.0
# NORM VECTOR: [1.2, 8.0, 0.4, 0.4, 1.6, 0.4, 0.32, 0.4]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 10 | False Positives = 16 | False Negatives = 218 | True Negatives = 1479
# Accuracy = 0.8642 | Precision = 0.3846 | Recall = 0.0439 | F1 Score = 0.0787
#
# GOLD: 45.0
# NORM VECTOR: [1.65, 11.0, 0.55, 0.55, 2.2, 0.55, 0.44, 0.55]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 10 | False Positives = 22 | False Negatives = 218 | True Negatives = 1473
# Accuracy = 0.8607 | Precision = 0.3125 | Recall = 0.0439 | F1 Score = 0.0769
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 9 | False Positives = 13 | False Negatives = 219 | True Negatives = 1482
# Accuracy = 0.8654 | Precision = 0.4091 | Recall = 0.0395 | F1 Score = 0.072
#
# GOLD: 45.0
# NORM VECTOR: [1.575, 10.5, 0.525, 0.525, 2.1, 0.525, 0.42, 0.525]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 9 | False Positives = 13 | False Negatives = 219 | True Negatives = 1482
# Accuracy = 0.8654 | Precision = 0.4091 | Recall = 0.0395 | F1 Score = 0.072
#
# GOLD: 45.0
# NORM VECTOR: [1.425, 9.5, 0.475, 0.475, 1.9, 0.475, 0.38, 0.475]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 7 | False Positives = 4 | False Negatives = 221 | True Negatives = 1491
# Accuracy = 0.8694 | Precision = 0.6364 | Recall = 0.0307 | F1 Score = 0.0586
#
# GOLD: 45.0
# NORM VECTOR: [1.5, 10.0, 0.5, 0.5, 2.0, 0.5, 0.4, 0.5]
# COL: ['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Mg (%)', 'CCPI', 'As (ppm)']
# True Positives = 7 | False Positives = 9 | False Negatives = 221 | True Negatives = 1486
# Accuracy = 0.8665 | Precision = 0.4375 | Recall = 0.0307 | F1 Score = 0.0574

# %%
area_1_data_frame
# Out:
#      SampleNumber        Easting      Northing   Latitude   Longitude  \
# 0          606516  554915.000000  3.375534e+06  30.510858 -110.427675
# 1          695001  557436.131684  3.377238e+06  30.526114 -110.401306
# 2          695002  557617.225660  3.377152e+06  30.525331 -110.399423
# 3          695003  557799.127065  3.377069e+06  30.524570 -110.397532
# 4          695004  557702.554000  3.377334e+06  30.526968 -110.398524
# ...           ...            ...           ...        ...         ...
# 1718      M023281  552192.000000  3.375676e+06  30.512261 -110.456045
# 1719      M023282  551880.000000  3.375962e+06  30.514855 -110.459283
# 1720      MRS-023  553747.101700  3.375146e+06        NaN         NaN
# 1721      MRS-024  554496.834800  3.376182e+06        NaN         NaN
# 1722      MRS-025  554129.815000  3.376937e+06        NaN         NaN
#
#       Elevation               Area       Type   Sampler  Au (ppm)  ...  \
# 0           NaN      La Mesa Ranch    Channel      LHRG    0.0100  ...
# 1        1272.0  San Antonio Ranch       Soil   PPV-JLO    0.0090  ...
# 2        1275.0  San Antonio Ranch       Soil   PPV-JLO    0.0060  ...
# 3        1316.0  San Antonio Ranch       Soil   PPV-JLO    0.0070  ...
# 4        1286.0  San Antonio Ranch       Soil   PPV-JLO    0.0050  ...
# ...         ...                ...        ...       ...       ...  ...
# 1718     1465.0       Arg.5_Molino  Chip-Rock        RS    0.0030  ...
# 1719     1423.0       Arg.5_Molino  Chip-Rock        RS    0.0005  ...
# 1720     1371.0            La Mesa  Rock Chip  Tectoniq    0.0080  ...
# 1721     1430.0            La Mesa  Rock Chip  Tectoniq    0.1240  ...
# 1722     1490.0            La Mesa  Rock Chip  Tectoniq    0.0080  ...
#
#       exp_2_17  exp_2_18  exp_2_19  exp_2_20  exp_2_21  exp_2_22  exp_2_23  \
# 0           TN        TN        TN        TN        TN        TN        TN
# 1           TN        TN        TN        TN        TN        TN        TN
# 2           TN        TN        TN        TN        TN        TN        TN
# 3           TN        TN        TN        TN        TN        TN        TN
# 4           TN        TN        TN        TN        TN        TN        TN
# ...        ...       ...       ...       ...       ...       ...       ...
# 1718        TN        TN        TN        TN        TN        TN        TN
# 1719        TN        TN        TN        TN        TN        TN        TN
# 1720        TN        TN        TN        TN        TN        TN        TN
# 1721        TN        TN        TN        TN        TN        TN        TN
# 1722        TN        TN        TN        TN        TN        TN        TN
#
#       exp_2_24  exp_2_25 exp_2_26
# 0           TN        TN       TN
# 1           TN        TN       TN
# 2           TN        TN       TN
# 3           TN        TN       TN
# 4           TN        TN       TN
# ...        ...       ...      ...
# 1718        TN        TN       TN
# 1719        TN        TN       TN
# 1720        TN        TN       TN
# 1721        TN        TN       TN
# 1722        TN        TN       TN
#
# [1723 rows x 176 columns]

# %%
exp_cols = [col for col in area_1_data_frame.columns if 'exp_' in col]

# %%
area_1_data_frame['TP'] = (area_1_data_frame[exp_cols] == 'TP').sum(axis=1)
area_1_data_frame['TN'] = (area_1_data_frame[exp_cols] == 'TN').sum(axis=1)
area_1_data_frame['FP'] = (area_1_data_frame[exp_cols] == 'FP').sum(axis=1)
area_1_data_frame['FN'] = (area_1_data_frame[exp_cols] == 'FN').sum(axis=1)

# %%
cols = list(area_2_data_frame.columns)
cols.extend(['TP', 'TN', 'FP', 'FN'])

# %%
area_1_data_frame[(area_1_data_frame['FP'] >= 30)].sort_values(by='FP', ascending=True)[cols].to_excel('CU_area2_45_TP_40%.xlsx', index=False)

# %%
area_1_data_frame
# Out:
#      SampleNumber        Easting      Northing   Latitude   Longitude  \
# 0        7VSS-001  551950.927104  3.363731e+06  30.404486 -110.459154
# 1        7VSS-002  551955.227104  3.363706e+06  30.404263 -110.459110
# 2        7VSS-003  551959.627104  3.363682e+06  30.404041 -110.459065
# 3        7VSS-004  551963.927104  3.363657e+06  30.403818 -110.459022
# 4        7VSS-005  551968.227104  3.363633e+06  30.403596 -110.458978
# ...           ...            ...           ...        ...         ...
# 3396      MRS-013  549057.226800  3.355597e+06        NaN         NaN
# 3397      MRS-026  551163.008700  3.357385e+06        NaN         NaN
# 3398      MRS-027  551158.888500  3.357368e+06        NaN         NaN
# 3399      MRS-029  552484.255100  3.358325e+06        NaN         NaN
# 3400      MRS-030  552569.535700  3.358464e+06        NaN         NaN
#
#       Elevation         Area       Type   Sampler  Au (ppm)  ...  exp_3_32  \
# 0           NaN    Oso Negro       Soil     RG, R    0.0060  ...        TN
# 1           NaN    Oso Negro       Soil     RG, R    0.0025  ...        TN
# 2           NaN    Oso Negro       Soil     RG, R    0.0025  ...        TN
# 3           NaN    Oso Negro       Soil     RG, R    0.0100  ...        TN
# 4           NaN    Oso Negro       Soil     RG, R    0.0025  ...        TN
# ...         ...          ...        ...       ...       ...  ...       ...
# 3396        NaN  Brecha Hill  Rock Chip  Tectoniq    0.0080  ...        TN
# 3397     1162.0    Bellota F  Rock Chip  Tectoniq    0.0720  ...        FN
# 3398     1174.0    Bellota F  Rock Chip  Tectoniq    0.0070  ...        FN
# 3399     1227.0        RdO W  Rock Chip  Tectoniq    0.0090  ...        TN
# 3400     1226.0        RdO N  Rock Chip  Tectoniq    0.0060  ...        FN
#
#       exp_3_33  exp_3_34  exp_3_35  exp_3_36  exp_3_37  TP  TN  FP  FN
# 0           TN        TN        TN        TN        TN   0  75  25   0
# 1           TN        TN        TN        TN        TN   0  71  29   0
# 2           TN        TN        TN        TN        TN   0  56  44   0
# 3           TN        TN        TN        TN        TN   0  56  44   0
# 4           TN        TN        TN        TN        TN   0  64  36   0
# ...        ...       ...       ...       ...       ...  ..  ..  ..  ..
# 3396        TN        TN        TN        TN        TN   0  81  19   0
# 3397        FN        FN        FN        FN        FN  41   0   0  59
# 3398        FN        FN        FN        FN        FN  11   0   0  89
# 3399        TN        TN        TN        TN        TN   0  78  22   0
# 3400        FN        FN        FN        FN        FN   6   0   0  94
#
# [3401 rows x 180 columns]

# %%
area_1_data_frame[(area_1_data_frame['FP'] >= 20)].sort_values(by='FP', ascending=True)[cols].to_excel('area2_data_frame_TP.xlsx', index=False)

# %%
counts = {col: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0} for col in exp_cols}

# %%
for col in exp_cols:
    if col in area_1_data_frame.columns:
        counts[col] = area_1_data_frame[col].value_counts().to_dict()

counts_df = pd.DataFrame(counts).fillna(0).astype(int)

# %%
counts_df
# Out:
#     exp_0_0  exp_0_1  exp_0_2  exp_0_3  exp_0_4  exp_0_5  exp_0_6  exp_0_7  \
# TN     3124     3050     3090     3180     3150     3152     3124     3152
# FP      132      206      166       76      136      104      132      104
# FN      111      105      108      123       85      119      111      119
# TP       34       40       37       22       30       26       34       26
#
#     exp_0_8  exp_0_9  ...  exp_2_34  exp_2_35  exp_2_36  exp_3_0  exp_3_1  \
# TN     3090     3074  ...      3167      3137      3137     3033     2933
# FP      166      212  ...        89       119       119      223      323
# FN      108       81  ...       124       115       115      105       95
# TP       37       34  ...        21        30        30       40       50
#
#     exp_3_2  exp_3_3  exp_3_4  exp_3_5  exp_3_6
# TN     3096     3104     3134     3173     3057
# FP      160      152      122       83      229
# FN      111      113      115      125       81
# TP       34       32       30       20       34
#
# [4 rows x 100 columns]

# %%
# Initialize a dictionary to store counts


# Count the occurrences of 'TP', 'TN', 'FP', 'FN' for each column
for col in experiment_columns:
    if col in area_1_data_frame.columns:
        counts[col] = area_1_data_frame[col].value_counts().to_dict()

# Convert counts dictionary to DataFrame for better visualization
counts_df = pd.DataFrame(counts).fillna(0).astype(int)

print(counts_df)
# Out:
#      SampleNumber        Easting      Northing   Latitude   Longitude  \
# 0        7VSS-001  551950.927104  3.363731e+06  30.404486 -110.459154
# 1        7VSS-002  551955.227104  3.363706e+06  30.404263 -110.459110
# 2        7VSS-003  551959.627104  3.363682e+06  30.404041 -110.459065
# 3        7VSS-004  551963.927104  3.363657e+06  30.403818 -110.459022
# 4        7VSS-005  551968.227104  3.363633e+06  30.403596 -110.458978
# ...           ...            ...           ...        ...         ...
# 3396      MRS-013  549057.226800  3.355597e+06        NaN         NaN
# 3397      MRS-026  551163.008700  3.357385e+06        NaN         NaN
# 3398      MRS-027  551158.888500  3.357368e+06        NaN         NaN
# 3399      MRS-029  552484.255100  3.358325e+06        NaN         NaN
# 3400      MRS-030  552569.535700  3.358464e+06        NaN         NaN
#
#       Elevation         Area       Type   Sampler  Au (ppm)  ...     Na/Al  \
# 0           NaN    Oso Negro       Soil     RG, R    0.0060  ...  0.028950
# 1           NaN    Oso Negro       Soil     RG, R    0.0025  ...  0.032380
# 2           NaN    Oso Negro       Soil     RG, R    0.0025  ...  0.023314
# 3           NaN    Oso Negro       Soil     RG, R    0.0100  ...  0.017911
# 4           NaN    Oso Negro       Soil     RG, R    0.0025  ...  0.090553
# ...         ...          ...        ...       ...       ...  ...       ...
# 3396        NaN  Brecha Hill  Rock Chip  Tectoniq    0.0080  ...  0.453792
# 3397     1162.0    Bellota F  Rock Chip  Tectoniq    0.0720  ...  0.024725
# 3398     1174.0    Bellota F  Rock Chip  Tectoniq    0.0070  ...  0.000000
# 3399     1227.0        RdO W  Rock Chip  Tectoniq    0.0090  ...  0.027517
# 3400     1226.0        RdO N  Rock Chip  Tectoniq    0.0060  ...  0.598826
#
#                             Geometry  DomainId                 DomainName  \
# 0     POINT (551950.927 3363731.127)       3.0  San Martin-Lupita-Diluvio
# 1     POINT (551955.227 3363706.427)       3.0  San Martin-Lupita-Diluvio
# 2     POINT (551959.627 3363681.827)       3.0  San Martin-Lupita-Diluvio
# 3     POINT (551963.927 3363657.227)       3.0  San Martin-Lupita-Diluvio
# 4     POINT (551968.227 3363632.627)       3.0  San Martin-Lupita-Diluvio
# ...                              ...       ...                        ...
# 3396  POINT (549057.227 3355597.270)       1.0                   Mercedes
# 3397  POINT (551163.009 3357384.736)       2.0        Klondike-Rey de Oro
# 3398  POINT (551158.889 3357367.956)       2.0        Klondike-Rey de Oro
# 3399  POINT (552484.255 3358325.156)       2.0        Klondike-Rey de Oro
# 3400  POINT (552569.536 3358464.188)       2.0        Klondike-Rey de Oro
#
#       AreaId                                   NormalizedVector  \
# 0        1.0  [0.20833333333333334, 0.03666666666666667, 0.0...
# 1        1.0  [0.2916666666666667, 0.07666666666666667, 0.04...
# 2        1.0  [0.355, 0.04, 0.04, 0.8914285714285715, 0.5933...
# 3        1.0  [0.3566666666666667, 0.02666666666666667, 0.03...
# 4        1.0  [0.36833333333333335, 0.06666666666666667, 0.1...
# ...      ...                                                ...
# 3396     1.0  [0.35833333333333334, 0.30333333333333334, 0.5...
# 3397     1.0  [0.2916666666666667, 0.03166666666666667, 0.03...
# 3398     1.0  [0.08666666666666667, 0.008333333333333333, 0....
# 3399     1.0  [0.20666666666666667, 0.008333333333333333, 0....
# 3400     1.0  [0.7566666666666667, 0.6616666666666667, 0.772...
#
#       OreDifference  Actual  Predicted classification
# 0          4.743750   False      False             TN
# 1          4.748061   False      False             TN
# 2          4.499411   False      False             TN
# 3          4.697573   False      False             TN
# 4          4.314926   False      False             TN
# ...             ...     ...        ...            ...
# 3396       4.908180   False      False             TN
# 3397     648.800333   False      False             TN
# 3398       1.959331   False       True             FP
# 3399       3.892529   False      False             TN
# 3400       3.245699   False      False             TN
#
# [3401 rows x 77 columns]

# %%
temp_df.iloc[i]
# Out:
# Experiment Name                                  Fe Ca Na K Al Cu Mg CCPI
# Name                                                     nervous-mole-575
# difference_threshold                                                  2.5
# normalization_vector            [ 6.   6.   4.   3.5 10.5 25.   4.5  0.6]
# GOLD_THRESHOLD                                                        2.0
# Weighted accuracy                                                  0.8892
# Weighted f1                                                        0.2767
# Weighted precision                                                   0.21
# Weighted recall                                                    0.4056
# fn                                                                  111.0
# fp                                                                  132.0
# tn                                                                 3120.0
# tp                                                                   34.0
# Loss                                                           110.392587
# Key Columns             [Fe (%), Ca (%), Na (%), K (%), Al (%), Cu (pp...
# Name: 107, dtype: object

# %%
# Out:
#                     Experiment Name                 Name  \
# 23  Fe K Al Cu CCPI K_(Al-Na) As_Al      sedate-mare-463
# 71  Fe K Al Cu CCPI K_(Al-Na) As_Al       useful-loon-44
# 53  Fe K Al Cu CCPI K_(Al-Na) As_Al       spiffy-pig-802
# 1   Fe K Al Cu CCPI K_(Al-Na) As_Al   exultant-snipe-354
# 41  Fe K Al Cu CCPI K_(Al-Na) As_Al     orderly-trout-95
# ..                              ...                  ...
# 7   Fe K Al Cu CCPI K_(Al-Na) As_Al    blushing-bear-671
# 77  Fe K Al Cu CCPI K_(Al-Na) As_Al   unequaled-boar-384
# 46  Fe K Al Cu CCPI K_(Al-Na) As_Al    tasteful-fawn-721
# 6   Fe K Al Cu CCPI K_(Al-Na) As_Al    painted-whale-146
# 76  Fe K Al Cu CCPI K_(Al-Na) As_Al  respected-skink-245
#
#     difference_threshold                         normalization_vector  \
# 23                   2.0  [ 6.5   3.5  10.5  32.5   0.65  0.55  0.65]
# 71                   2.5         [ 6.   3.  10.  30.   0.6  0.5  0.6]
# 53                   2.0         [ 7.   4.  11.  35.   0.7  0.6  0.7]
# 1                    2.5         [ 5.5  2.5  9.5 30.   0.6  0.5  0.6]
# 41                   2.5  [ 5.5   2.5   9.5  27.5   0.55  0.45  0.55]
# ..                   ...                                          ...
# 7                    1.0         [ 5.5  2.5  9.5 30.   0.6  0.5  0.6]
# 77                   1.0         [ 6.   3.  10.  30.   0.6  0.5  0.6]
# 46                   1.0  [ 5.5   2.5   9.5  27.5   0.55  0.45  0.55]
# 6                    1.0         [ 5.5  2.5  9.5 30.   0.6  0.5  0.6]
# 76                   1.0         [ 6.   3.  10.  30.   0.6  0.5  0.6]
#
#     GOLD_THRESHOLD  Weighted accuracy  Weighted f1  Weighted precision  \
# 23             2.0             0.9020       0.2506              0.2001
# 71             2.0             0.8814       0.2464              0.1788
# 53             2.0             0.8907       0.2464              0.1856
# 1              2.0             0.8861       0.2443              0.1802
# 41             2.0             0.8928       0.2423              0.1853
# ..             ...                ...          ...                 ...
# 7              2.0             0.9426       0.0920              0.1989
# 77             2.0             0.9415       0.0898              0.1880
# 46             2.5             0.9501       0.0823              0.1477
# 6              2.5             0.9509       0.0819              0.1499
# 76             2.5             0.9498       0.0797              0.1416
#
#     Weighted recall     fn     fp      tn    tp        Loss  \
# 23           0.3352  115.0  122.0  3130.0  30.0  118.718922
# 71           0.3962  108.0  178.0  3074.0  37.0  129.132228
# 53           0.3662  111.0  155.0  3097.0  34.0  142.579623
# 1            0.3791  110.0  167.0  3085.0  35.0  121.538896
# 41           0.3501  114.0  142.0  3110.0  31.0  106.370683
# ..              ...    ...    ...     ...   ...         ...
# 7            0.0599  141.0   15.0  3237.0   4.0   61.732289
# 77           0.0590  141.0   16.0  3236.0   4.0   64.592948
# 46           0.0571  112.0   16.0  3266.0   3.0   50.830113
# 6            0.0564  112.0   16.0  3266.0   3.0   54.035875
# 76           0.0555  112.0   17.0  3265.0   3.0   56.776653
#
#                                           Key Columns
# 23  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 71  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 53  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 1   [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 41  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# ..                                                ...
# 7   [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 77  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 46  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 6   [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
# 76  [Fe (%), K (%), Al (%), Cu (ppm), CCPI, K/(Al-...
#
# [62 rows x 15 columns]

# %%
eval(key_columns)
# Out:
# ['Fe (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'CCPI', 'K/(Al-Na)', 'As/Al']

# %%
all_exp['Experiment Name'].unique()
# Out:
# array(['Fe Ca Na K Al Cu Mg CCPI',
#        'Fe Ca Na K Al Cu Mg CCPI Ishikawa Na_Al',
#        'Fe Ca Na K Al Cu Mg CCPI Ishikawa',
#        'Fe K Al Cu CCPI K_(Al-Na) As_Al'], dtype=object)

# %%
['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI']
['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI', 'Ishikawa', 'Na/Al']
['Fe (%)', 'Ca (%)', 'Na (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'Mg (%)', 'CCPI', 'Ishikawa']
['Fe (%)', 'K (%)', 'Al (%)', 'Cu (ppm)', 'CCPI', 'K/(Al-Na)', 'As/Al']
